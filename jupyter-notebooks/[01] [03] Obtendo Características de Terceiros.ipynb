# %%
import pandas as pd

df = pd.read_csv('Dataset/Generated/attributes.csv')
df = df.fillna('')

# %%
from IPy import IP
def ip_check(s):
    try:
        IP(s)
        return 1
    except:
        return 0
    
from whois import whois
def try_whois(s):
    try:
        return whois(s)
    except:
        return 0       

from ipwhois import IPWhois    
def try_ipwhois(s):
    try:
        return IPWhois(s).lookup_whois()
    except:
        return 0 
    
def get_cdt(s):
    if ip_check(s):
        return 1
    else:
        return try_whois(s)

# %%
# df['Características de Terceiros'] = df['domain'].apply(get_cdt)

# %%
# df['Características de Terceiros 2'] = df['domain'].apply(get_cdt)
# Out:
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# Error trying to connect to socket: closing socket
# ...

# %%
# def merge(b, s1, s2):
#     if b:
#         return s1
#     return s2

# df['Third Party'] = df.apply(lambda x: merge(x['ip_format'],
#                                              x['Características de Terceiros'],
#                                              x['Características de Terceiros 2']),
#                                        axis = 1)

# %%
def get_cdt(s):
    if ip_check(s):
        return try_ipwhois(s)
    else:
        return try_whois(s)
    
df['Third Party'] = df['domain'].apply(get_cdt)

# %%
df_subset.to_pickle('Dataset/Generated/brute_tp_characteristics.pickle')
